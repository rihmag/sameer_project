# %% [markdown]
# # Weapon Detection Training Notebook
#
# This notebook provides the environment to train a YOLO model specifically for weapon detection using your custom dataset.

# %%
# Install the ultralytics package if not already installed
# !pip install ultralytics
# !pip install mediapipe
# Out:
# Requirement already satisfied: ultralytics in /Users/anantgambhir/opt/anaconda3/lib/python3.13/site-packages (8.4.37)
# Requirement already satisfied: numpy>=1.23.0 in /Users/anantgambhir/opt/anaconda3/lib/python3.13/site-packages (from ultralytics) (2.1.3)
# Requirement already satisfied: matplotlib>=3.3.0 in /Users/anantgambhir/opt/anaconda3/lib/python3.13/site-packages (from ultralytics) (3.10.0)
# Requirement already satisfied: opencv-python>=4.6.0 in /Users/anantgambhir/opt/anaconda3/lib/python3.13/site-packages (from ultralytics) (4.13.0.92)
# Requirement already satisfied: pillow>=7.1.2 in /Users/anantgambhir/opt/anaconda3/lib/python3.13/site-packages (from ultralytics) (11.1.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /Users/anantgambhir/opt/anaconda3/lib/python3.13/site-packages (from ultralytics) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in /Users/anantgambhir/opt/anaconda3/lib/python3.13/site-packages (from ultralytics) (2.32.5)
# Requirement already satisfied: scipy>=1.4.1 in /Users/anantgambhir/opt/anaconda3/lib/python3.13/site-packages (from ultralytics) (1.15.3)
# Requirement already satisfied: torch>=1.8.0 in /Users/anantgambhir/opt/anaconda3/lib/python3.13/site-packages (from ultralytics) (2.8.0)
# Requirement already satisfied: torchvision>=0.9.0 in /Users/anantgambhir/opt/anaconda3/lib/python3.13/site-packages (from ultralytics) (0.23.0)
# Requirement already satisfied: psutil>=5.8.0 in /Users/anantgambhir/opt/anaconda3/lib/python3.13/site-packages (from ultralytics) (5.9.0)
# Requirement already satisfied: polars>=0.20.0 in /Users/anantgambhir/opt/anaconda3/lib/python3.13/site-packages (from ultralytics) (1.39.3)
# Requirement already satisfied: ultralytics-thop>=2.0.18 in /Users/anantgambhir/opt/anaconda3/lib/python3.13/site-packages (from ultralytics) (2.0.18)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/anantgambhir/opt/anaconda3/lib/python3.13/site-packages (from matplotlib>=3.3.0->ultralytics) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /Users/anantgambhir/opt/anaconda3/lib/python3.13/site-packages (from matplotlib>=3.3.0->ultralytics) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/anantgambhir/opt/anaconda3/lib/python3.13/site-packages (from matplotlib>=3.3.0->ultralytics) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/anantgambhir/opt/anaconda3/lib/python3.13/site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /Users/anantgambhir/opt/anaconda3/lib/python3.13/site-packages (from matplotlib>=3.3.0->ultralytics) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/anantgambhir/opt/anaconda3/lib/python3.13/site-packages (from matplotlib>=3.3.0->ultralytics) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/anantgambhir/opt/anaconda3/lib/python3.13/site-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: polars-runtime-32==1.39.3 in /Users/anantgambhir/opt/anaconda3/lib/python3.13/site-packages (from polars>=0.20.0->ultralytics) (1.39.3)
# Requirement already satisfied: six>=1.5 in /Users/anantgambhir/opt/anaconda3/lib/python3.13/site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/anantgambhir/opt/anaconda3/lib/python3.13/site-packages (from requests>=2.23.0->ultralytics) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/anantgambhir/opt/anaconda3/lib/python3.13/site-packages (from requests>=2.23.0->ultralytics) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/anantgambhir/opt/anaconda3/lib/python3.13/site-packages (from requests>=2.23.0->ultralytics) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/anantgambhir/opt/anaconda3/lib/python3.13/site-packages (from requests>=2.23.0->ultralytics) (2025.8.3)
# Requirement already satisfied: filelock in /Users/anantgambhir/opt/anaconda3/lib/python3.13/site-packages (from torch>=1.8.0->ultralytics) (3.17.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /Users/anantgambhir/opt/anaconda3/lib/python3.13/site-packages (from torch>=1.8.0->ultralytics) (4.12.2)
# Requirement already satisfied: setuptools in /Users/anantgambhir/opt/anaconda3/lib/python3.13/site-packages (from torch>=1.8.0->ultralytics) (72.1.0)
# Requirement already satisfied: sympy>=1.13.3 in /Users/anantgambhir/opt/anaconda3/lib/python3.13/site-packages (from torch>=1.8.0->ultralytics) (1.13.3)
# Requirement already satisfied: networkx in /Users/anantgambhir/opt/anaconda3/lib/python3.13/site-packages (from torch>=1.8.0->ultralytics) (3.4.2)
# Requirement already satisfied: jinja2 in /Users/anantgambhir/opt/anaconda3/lib/python3.13/site-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec in /Users/anantgambhir/opt/anaconda3/lib/python3.13/site-packages (from torch>=1.8.0->ultralytics) (2025.3.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/anantgambhir/opt/anaconda3/lib/python3.13/site-packages (from sympy>=1.13.3->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/anantgambhir/opt/anaconda3/lib/python3.13/site-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.2)
# Requirement already satisfied: mediapipe in /Users/anantgambhir/opt/anaconda3/lib/python3.13/site-packages (0.10.33)
# Requirement already satisfied: absl-py~=2.3 in /Users/anantgambhir/opt/anaconda3/lib/python3.13/site-packages (from mediapipe) (2.4.0)
# Requirement already satisfied: numpy in /Users/anantgambhir/opt/anaconda3/lib/python3.13/site-packages (from mediapipe) (2.1.3)
# Requirement already satisfied: sounddevice~=0.5 in /Users/anantgambhir/opt/anaconda3/lib/python3.13/site-packages (from mediapipe) (0.5.5)
# Requirement already satisfied: flatbuffers~=25.9 in /Users/anantgambhir/opt/anaconda3/lib/python3.13/site-packages (from mediapipe) (25.9.23)
# Requirement already satisfied: opencv-contrib-python in /Users/anantgambhir/opt/anaconda3/lib/python3.13/site-packages (from mediapipe) (4.12.0.88)
# Requirement already satisfied: matplotlib in /Users/anantgambhir/opt/anaconda3/lib/python3.13/site-packages (from mediapipe) (3.10.0)
# Requirement already satisfied: cffi in /Users/anantgambhir/opt/anaconda3/lib/python3.13/site-packages (from sounddevice~=0.5->mediapipe) (1.17.1)
# Requirement already satisfied: pycparser in /Users/anantgambhir/opt/anaconda3/lib/python3.13/site-packages (from cffi->sounddevice~=0.5->mediapipe) (2.21)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/anantgambhir/opt/anaconda3/lib/python3.13/site-packages (from matplotlib->mediapipe) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /Users/anantgambhir/opt/anaconda3/lib/python3.13/site-packages (from matplotlib->mediapipe) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/anantgambhir/opt/anaconda3/lib/python3.13/site-packages (from matplotlib->mediapipe) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/anantgambhir/opt/anaconda3/lib/python3.13/site-packages (from matplotlib->mediapipe) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /Users/anantgambhir/opt/anaconda3/lib/python3.13/site-packages (from matplotlib->mediapipe) (24.2)
# Requirement already satisfied: pillow>=8 in /Users/anantgambhir/opt/anaconda3/lib/python3.13/site-packages (from matplotlib->mediapipe) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/anantgambhir/opt/anaconda3/lib/python3.13/site-packages (from matplotlib->mediapipe) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/anantgambhir/opt/anaconda3/lib/python3.13/site-packages (from matplotlib->mediapipe) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /Users/anantgambhir/opt/anaconda3/lib/python3.13/site-packages (from python-dateutil>=2.7->matplotlib->mediapipe) (1.17.0)

# %%
from ultralytics import YOLO
import os
import torch

# Check M5 MPS availability
if torch.backends.mps.is_available():
    print("✅ Apple M5 MPS GPU detected — using Metal acceleration")
else:
    print("⚠️ MPS not available — falling back to CPU")

model = YOLO('yolov8s.pt')  # nano = faster on M5

dataset_path = os.path.abspath('more_dataset/data.yaml')
if not os.path.exists(dataset_path):
    raise FileNotFoundError(
        f'Could not find {dataset_path}. '
        f'Please ensure data.yaml exists in the current directory.'
    )

results = model.train(
    data=dataset_path,
    epochs=25,          # ⬇ reduced from 100
    imgsz=416,          # ⬇ reduced from 640 (faster on M5)
    batch=16,
    name='weapon_yolo_model',

    device='mps',       # ✅ Apple Silicon — M1/M2/M3/M4/M5
    workers=4,          # M5 has good CPU cores, keep at 4
    patience=15,        # ⬇ stop earlier if no improvement
    save_period=10,

    # Optimizer
    lr0=0.01,
    lrf=0.001,
    momentum=0.937,
    weight_decay=0.0005,

    # Lighter augmentation = faster training
    hsv_h=0.015,
    hsv_s=0.7,
    hsv_v=0.4,
    fliplr=0.5,
    flipud=0.0,         # ⬇ disabled
    mosaic=0.5,         # ⬇ reduced from 1.0
    mixup=0.0,          # ⬇ disabled
    amp=False,          # ❌ disable — MPS has issues with mixed precision
)

print("\n✅ Training Complete!")
print(f"Best model saved at: runs/detect/weapon_yolo_model/weights/best.pt")
# Out:
# ✅ Apple M5 MPS GPU detected — using Metal acceleration
# Ultralytics 8.4.37 🚀 Python-3.13.5 torch-2.8.0 MPS (Apple M5)
# engine/trainer: agnostic_nms=False, amp=False, angle=1.0, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, cls_pw=0.0, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/Users/anantgambhir/Hello Ji/sameer_project/more_dataset/data.yaml, degrees=0.0, deterministic=True, device=mps, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=25, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=416, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.001, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolov8s.pt, momentum=0.937, mosaic=0.5, multi_scale=0.0, name=weapon_yolo_model11, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=15, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/Users/anantgambhir/Hello Ji/sameer_project/runs/detect/weapon_yolo_model11, save_frames=False, save_json=False, save_period=10, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=4, workspace=None
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 20
#      14 if not os.path.exists(dataset_path):
#      15     raise FileNotFoundError(
#      16         f'Could not find {dataset_path}. '
#      17         f'Please ensure data.yaml exists in the current directory.'
#      18     )
# ---> 20 results = model.train(
#      21     data=dataset_path,
#      22     epochs=25,          # ⬇ reduced from 100
#      23     imgsz=416,          # ⬇ reduced from 640 (faster on M5)
#      24     batch=16,
#      25     name='weapon_yolo_model',
#      26
#      27     device='mps',       # ✅ Apple Silicon — M1/M2/M3/M4/M5
#      28     workers=4,          # M5 has good CPU cores, keep at 4
#      29     patience=15,        # ⬇ stop earlier if no improvement
#      30     save_period=10,
#      31
#      32     # Optimizer
#      33     lr0=0.01,
#      34     lrf=0.001,
#      35     momentum=0.937,
#      36     weight_decay=0.0005,
#      37
#      38     # Lighter augmentation = faster training
#      39     hsv_h=0.015,
#      40     hsv_s=0.7,
#      41     hsv_v=0.4,
#      42     fliplr=0.5,
#      43     flipud=0.0,         # ⬇ disabled
#      44     mosaic=0.5,         # ⬇ reduced from 1.0
#      45     mixup=0.0,          # ⬇ disabled
#      46     amp=False,          # ❌ disable — MPS has issues with mixed precision
#      47 )
#      49 print("\n✅ Training Complete!")
#      50 print(f"Best model saved at: runs/detect/weapon_yolo_model/weights/best.pt")
#
# File ~/opt/anaconda3/lib/python3.13/site-packages/ultralytics/engine/model.py:781, in Model.train(self, trainer, **kwargs)
#     774             LOGGER.warning(
#     775                 f"model '{self.ckpt_path}' is not a resumable training checkpoint "
#     776                 f"(missing epoch/optimizer state). Use 'resume' only to continue incomplete training. "
#     777                 f"Starting new training instead."
#     778             )
#     779             args["resume"] = False
# --> 781 self.trainer = (trainer or self._smart_load("trainer"))(overrides=args, _callbacks=self.callbacks)
#     782 if not args.get("resume") and self.ckpt:
#     783     # Reuse the already-loaded checkpoint model to avoid re-resolving remote weight sources during trainer setup.
#     784     self.trainer.model = self.trainer.get_model(weights=self.model, cfg=self.model.yaml)
#
# File ~/opt/anaconda3/lib/python3.13/site-packages/ultralytics/models/yolo/detect/train.py:63, in DetectionTrainer.__init__(self, cfg, overrides, _callbacks)
#      55 def __init__(self, cfg=DEFAULT_CFG, overrides: dict[str, Any] | None = None, _callbacks: dict | None = None):
#      56     """Initialize a DetectionTrainer object for training YOLO object detection models.
#      57
#      58     Args:
#    (...)
#      61         _callbacks (dict, optional): Dictionary of callback functions to be executed during training.
#      62     """
# ---> 63     super().__init__(cfg, overrides, _callbacks)
#
# File ~/opt/anaconda3/lib/python3.13/site-packages/ultralytics/engine/trainer.py:186, in BaseTrainer.__init__(self, cfg, overrides, _callbacks)
#     184 self.model = check_model_file_from_stem(self.args.model)  # add suffix, i.e. yolo26n -> yolo26n.pt
#     185 with torch_distributed_zero_first(LOCAL_RANK):  # avoid auto-downloading dataset multiple times
# --> 186     self.data = self.get_dataset()
#     188 self.ema = None
#     190 # Optimization utils init
#
# File ~/opt/anaconda3/lib/python3.13/site-packages/ultralytics/engine/trainer.py:705, in BaseTrainer.get_dataset(self)
#     698     data = check_cls_dataset(self.args.data)
#     699 elif str(self.args.data).rsplit(".", 1)[-1] in {"yaml", "yml"} or self.args.task in {
#     700     "detect",
#     701     "segment",
#     702     "pose",
#     703     "obb",
#     704 }:
# --> 705     data = check_det_dataset(self.args.data)
#     706     if "yaml_file" in data:
#     707         self.args.data = data["yaml_file"]  # for validating 'yolo train data=url.zip' usage
#
# File ~/opt/anaconda3/lib/python3.13/site-packages/ultralytics/data/utils.py:492, in check_det_dataset(dataset, autodownload)
#     490         s = f"success ✅ {dt}, saved to {colorstr('bold', DATASETS_DIR)}" if r in {0, None} else f"failure {dt} ❌"
#     491         LOGGER.info(f"Dataset download {s}\n")
# --> 492 check_font("Arial.ttf" if is_ascii(data["names"]) else "Arial.Unicode.ttf")  # download fonts
#     494 return data
#
# File ~/opt/anaconda3/lib/python3.13/site-packages/ultralytics/utils/__init__.py:519, in ThreadingLocked.__call__.<locals>.decorated(*args, **kwargs)
#     517 """Apply thread-safety to the decorated function or method."""
#     518 with self.lock:
# --> 519     return f(*args, **kwargs)
#
# File ~/opt/anaconda3/lib/python3.13/site-packages/ultralytics/utils/checks.py:339, in check_font(font)
#     336     return file
#     338 # Check system fonts
# --> 339 matches = [s for s in font_manager.findSystemFonts() if font in s]
#     340 if any(matches):
#     341     return matches[0]
#
# File ~/opt/anaconda3/lib/python3.13/site-packages/matplotlib/font_manager.py:293, in findSystemFonts(fontpaths, fontext)
#     291 installed_fonts = _get_fontconfig_fonts()
#     292 if sys.platform == 'darwin':
# --> 293     installed_fonts += _get_macos_fonts()
#     294     fontpaths = [*X11FontDirectories, *OSXFontDirectories]
#     295 else:
#
# File ~/opt/anaconda3/lib/python3.13/site-packages/matplotlib/font_manager.py:269, in _get_macos_fonts()
#     266 """Cache and list the font paths known to ``system_profiler SPFontsDataType``."""
#     267 try:
#     268     d, = plistlib.loads(
# --> 269         subprocess.check_output(["system_profiler", "-xml", "SPFontsDataType"]))
#     270 except (OSError, subprocess.CalledProcessError, plistlib.InvalidFileException):
#     271     return []
#
# File ~/opt/anaconda3/lib/python3.13/subprocess.py:472, in check_output(timeout, *popenargs, **kwargs)
#     469         empty = b''
#     470     kwargs['input'] = empty
# --> 472 return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
#     473            **kwargs).stdout
#
# File ~/opt/anaconda3/lib/python3.13/subprocess.py:556, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     554 with Popen(*popenargs, **kwargs) as process:
#     555     try:
# --> 556         stdout, stderr = process.communicate(input, timeout=timeout)
#     557     except TimeoutExpired as exc:
#     558         process.kill()
#
# File ~/opt/anaconda3/lib/python3.13/subprocess.py:1209, in Popen.communicate(self, input, timeout)
#    1207     self._stdin_write(input)
#    1208 elif self.stdout:
# -> 1209     stdout = self.stdout.read()
#    1210     self.stdout.close()
#    1211 elif self.stderr:
#
# KeyboardInterrupt:

# %%
# Out:
# ✅ Apple M5 MPS GPU detected — using Metal acceleration
# Ultralytics 8.4.37 🚀 Python-3.13.5 torch-2.8.0 MPS (Apple M5)
# engine/trainer: agnostic_nms=False, amp=False, angle=1.0, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, cls_pw=0.0, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/Users/anantgambhir/Hello Ji/sameer_project/abc2/data.yaml, degrees=0.0, deterministic=True, device=mps, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=25, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=416, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.001, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolov8s.pt, momentum=0.937, mosaic=0.5, multi_scale=0.0, name=weapon_yolo_model31, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=15, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/Users/anantgambhir/Hello Ji/sameer_project/runs/detect/weapon_yolo_model31, save_frames=False, save_json=False, save_period=10, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=4, workspace=None
# Overriding model.yaml nc=80 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     29056  ultralytics.nn.modules.block.C2f             [64, 64, 1, True]
#   3                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   4                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   5                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   6                  -1  2    788480  ultralytics.nn.modules.block.C2f             [256, 256, 2, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   8                  -1  1   1838080  ultralytics.nn.modules.block.C2f             [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    591360  ultralytics.nn.modules.block.C2f             [768, 256, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  16                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  19                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1   1969152  ultralytics.nn.modules.block.C2f             [768, 512, 1]
#  22        [15, 18, 21]  1   2116435  ultralytics.nn.modules.head.Detect           [1, 16, None, [128, 256, 512]]
# Model summary: 130 layers, 11,135,987 parameters, 11,135,971 gradients, 28.6 GFLOPs
#
# Transferred 349/355 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 7233.2±2215.2 MB/s, size: 224.8 KB)
# train: Scanning /Users/anantgambhir/Hello Ji/sameer_project/abc2/labels... 103 images, 0 backgrounds, 103 corrupt: 100% ━━━━━━━━━━━━ 103/103 7.4Kit/s 0.0s
# train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_1.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
# train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_10.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
# train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_100.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
# train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_101.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
# train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_102.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
# train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_103.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
# train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_11.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
# train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_12.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
# train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_13.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
# train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_14.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
# train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_15.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
# train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_16.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
# train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_17.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
# train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_18.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
# train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_19.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
# train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_2.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
# train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_20.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
# train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_21.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
# train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_22.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
# train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_23.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
# train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_24.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
# train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_25.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
# train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_26.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
# train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_27.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
# train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_28.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
# train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_29.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
# train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_3.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
# train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_30.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
# train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_31.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
# train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_32.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
# train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_33.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
# train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_34.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
# train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_35.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
# train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_36.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
# train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_37.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
# train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_38.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
# train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_39.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
# train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_4.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
# train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_40.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
# train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_41.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
# train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_42.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
# train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_43.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
# train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_44.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
# train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_45.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
# train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_46.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
# train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_47.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
# train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_48.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
# train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_49.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
# train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_5.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
# train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_50.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
# train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_51.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
# train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_52.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
# train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_53.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
# train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_54.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
# train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_55.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
# train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_56.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
# train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_57.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
# train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_58.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
# train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_59.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
# train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_6.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
# train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_60.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
# train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_61.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
# train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_62.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
# train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_63.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
# train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_64.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
# train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_65.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
# train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_66.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
# train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_67.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
# train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_68.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
# train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_69.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
# train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_7.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
# train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_70.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
# train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_71.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
# train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_72.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
# train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_73.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
# train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_74.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
# train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_75.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
# train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_76.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
# train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_77.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
# train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_78.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
# train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_79.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
# train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_8.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
# train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_80.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
# train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_81.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
# train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_82.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
# train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_83.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
# train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_84.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
# train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_85.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
# train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_86.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
# train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_87.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
# train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_88.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
# train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_89.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
# train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_9.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
# train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_90.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
# train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_91.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
# train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_92.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
# train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_93.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
# train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_94.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
# train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_95.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
# train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_96.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
# train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_97.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
# train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_98.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
# train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_99.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[3], line 20
#      14 if not os.path.exists(dataset_path):
#      15     raise FileNotFoundError(
#      16         f'Could not find {dataset_path}. '
#      17         f'Please ensure data.yaml exists in the current directory.'
#      18     )
# ---> 20 results = model.train(
#      21     data=dataset_path,
#      22     epochs=25,          # ⬇ reduced from 100
#      23     imgsz=416,          # ⬇ reduced from 640 (faster on M5)
#      24     batch=16,
#      25     name='weapon_yolo_model',
#      26
#      27     device='mps',       # ✅ Apple Silicon — M1/M2/M3/M4/M5
#      28     workers=4,          # M5 has good CPU cores, keep at 4
#      29     patience=15,        # ⬇ stop earlier if no improvement
#      30     save_period=10,
#      31
#      32     # Optimizer
#      33     lr0=0.01,
#      34     lrf=0.001,
#      35     momentum=0.937,
#      36     weight_decay=0.0005,
#      37
#      38     # Lighter augmentation = faster training
#      39     hsv_h=0.015,
#      40     hsv_s=0.7,
#      41     hsv_v=0.4,
#      42     fliplr=0.5,
#      43     flipud=0.0,         # ⬇ disabled
#      44     mosaic=0.5,         # ⬇ reduced from 1.0
#      45     mixup=0.0,          # ⬇ disabled
#      46     amp=False,          # ❌ disable — MPS has issues with mixed precision
#      47 )
#
# File ~/opt/anaconda3/lib/python3.13/site-packages/ultralytics/engine/model.py:787, in Model.train(self, trainer, **kwargs)
#     784     self.trainer.model = self.trainer.get_model(weights=self.model, cfg=self.model.yaml)
#     785     self.model = self.trainer.model
# --> 787 self.trainer.train()
#     788 # Update model and cfg after training
#     789 if RANK in {-1, 0}:
#
# File ~/opt/anaconda3/lib/python3.13/site-packages/ultralytics/engine/trainer.py:246, in BaseTrainer.train(self)
#     243             ddp_cleanup(self, str(file))
#     245 else:
# --> 246     self._do_train()
#
# File ~/opt/anaconda3/lib/python3.13/site-packages/ultralytics/engine/trainer.py:369, in BaseTrainer._do_train(self)
#     367 if self.world_size > 1:
#     368     self._setup_ddp()
# --> 369 self._setup_train()
#     371 nb = len(self.train_loader)  # number of batches
#     372 nw = max(round(self.args.warmup_epochs * nb), 100) if self.args.warmup_epochs > 0 else -1  # warmup iterations
#
# File ~/opt/anaconda3/lib/python3.13/site-packages/ultralytics/engine/trainer.py:350, in BaseTrainer._setup_train(self)
#     347 if self.batch_size < 1 and RANK == -1:  # single-GPU only, estimate best batch size
#     348     self.args.batch = self.batch_size = self.auto_batch()
# --> 350 self._build_train_pipeline()
#     351 self.validator = self.get_validator()
#     352 self.ema = ModelEMA(self.model)
#
# File ~/opt/anaconda3/lib/python3.13/site-packages/ultralytics/engine/trainer.py:271, in BaseTrainer._build_train_pipeline(self)
#     269 """Build dataloaders, optimizer, and scheduler for current batch size."""
#     270 batch_size = self.batch_size // max(self.world_size, 1)
# --> 271 self.train_loader = self.get_dataloader(
#     272     self.data["train"], batch_size=batch_size, rank=LOCAL_RANK, mode="train"
#     273 )
#     274 # Note: When training DOTA dataset, double batch size could get OOM on images with >2000 objects.
#     275 self.test_loader = self.get_dataloader(
#     276     self.data.get("val") or self.data.get("test"),
#     277     batch_size=batch_size if self.args.task == "obb" else batch_size * 2,
#     278     rank=LOCAL_RANK,
#     279     mode="val",
#     280 )
#
# File ~/opt/anaconda3/lib/python3.13/site-packages/ultralytics/models/yolo/detect/train.py:93, in DetectionTrainer.get_dataloader(self, dataset_path, batch_size, rank, mode)
#      91 assert mode in {"train", "val"}, f"Mode must be 'train' or 'val', not {mode}."
#      92 with torch_distributed_zero_first(rank):  # init dataset *.cache only once if DDP
# ---> 93     dataset = self.build_dataset(dataset_path, mode, batch_size)
#      94 shuffle = mode == "train"
#      95 if getattr(dataset, "rect", False) and shuffle and not np.all(dataset.batch_shapes == dataset.batch_shapes[0]):
#
# File ~/opt/anaconda3/lib/python3.13/site-packages/ultralytics/models/yolo/detect/train.py:77, in DetectionTrainer.build_dataset(self, img_path, mode, batch)
#      66 """Build YOLO Dataset for training or validation.
#      67
#      68 Args:
#    (...)
#      74     (Dataset): YOLO dataset object configured for the specified mode.
#      75 """
#      76 gs = max(int(unwrap_model(self.model).stride.max()), 32)
# ---> 77 return build_yolo_dataset(self.args, img_path, batch, self.data, mode=mode, rect=mode == "val", stride=gs)
#
# File ~/opt/anaconda3/lib/python3.13/site-packages/ultralytics/data/build.py:236, in build_yolo_dataset(cfg, img_path, batch, data, mode, rect, stride, multi_modal)
#     234 """Build and return a YOLO dataset based on configuration parameters."""
#     235 dataset = YOLOMultiModalDataset if multi_modal else YOLODataset
# --> 236 return dataset(
#     237     img_path=img_path,
#     238     imgsz=cfg.imgsz,
#     239     batch_size=batch,
#     240     augment=mode == "train",  # augmentation
#     241     hyp=cfg,  # TODO: probably add a get_hyps_from_cfg function
#     242     rect=cfg.rect or rect,  # rectangular batches
#     243     cache=cfg.cache or None,
#     244     single_cls=cfg.single_cls or False,
#     245     stride=stride,
#     246     pad=0.0 if mode == "train" else 0.5,
#     247     prefix=colorstr(f"{mode}: "),
#     248     task=cfg.task,
#     249     classes=cfg.classes,
#     250     data=data,
#     251     fraction=cfg.fraction if mode == "train" else 1.0,
#     252 )
#
# File ~/opt/anaconda3/lib/python3.13/site-packages/ultralytics/data/dataset.py:88, in YOLODataset.__init__(self, data, task, *args, **kwargs)
#      86 self.data = data
#      87 assert not (self.use_segments and self.use_keypoints), "Can not use both segments and keypoints."
# ---> 88 super().__init__(*args, channels=self.data.get("channels", 3), **kwargs)
#
# File ~/opt/anaconda3/lib/python3.13/site-packages/ultralytics/data/base.py:118, in BaseDataset.__init__(self, img_path, imgsz, cache, augment, hyp, prefix, rect, batch_size, stride, pad, single_cls, classes, fraction, channels)
#     116 self.cv2_flag = cv2.IMREAD_GRAYSCALE if channels == 1 else cv2.IMREAD_COLOR
#     117 self.im_files = self.get_img_files(self.img_path)
# --> 118 self.labels = self.get_labels()
#     119 self.update_labels(include_class=classes)  # single_cls and include_class
#     120 self.ni = len(self.labels)  # number of images
#
# File ~/opt/anaconda3/lib/python3.13/site-packages/ultralytics/data/dataset.py:187, in YOLODataset.get_labels(self)
#     185 if not labels:
#     186     issues = "\n  ".join(sorted(set(cache["msgs"]))) or "no error details"
# --> 187     raise RuntimeError(f"No valid images found in {cache_path}.\n  {issues}\n{HELP_URL}")
#     188 [cache.pop(k) for k in ("hash", "version", "msgs")]  # remove items
#     189 self.im_files = [lb["im_file"] for lb in labels]  # update im_files
#
# RuntimeError: No valid images found in /Users/anantgambhir/Hello Ji/sameer_project/abc2/labels.cache.
#   train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_1.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
#   train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_10.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
#   train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_100.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
#   train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_101.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
#   train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_102.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
#   train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_103.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
#   train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_11.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
#   train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_12.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
#   train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_13.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
#   train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_14.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
#   train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_15.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
#   train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_16.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
#   train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_17.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
#   train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_18.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
#   train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_19.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
#   train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_2.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
#   train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_20.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
#   train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_21.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
#   train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_22.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
#   train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_23.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
#   train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_24.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
#   train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_25.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
#   train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_26.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
#   train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_27.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
#   train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_28.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
#   train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_29.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
#   train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_3.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
#   train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_30.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
#   train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_31.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
#   train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_32.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
#   train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_33.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
#   train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_34.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
#   train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_35.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
#   train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_36.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
#   train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_37.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
#   train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_38.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
#   train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_39.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
#   train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_4.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
#   train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_40.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
#   train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_41.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
#   train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_42.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
#   train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_43.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
#   train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_44.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
#   train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_45.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
#   train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_46.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
#   train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_47.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
#   train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_48.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
#   train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_49.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
#   train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_5.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
#   train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_50.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
#   train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_51.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
#   train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_52.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
#   train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_53.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
#   train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_54.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
#   train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_55.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
#   train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_56.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
#   train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_57.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
#   train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_58.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
#   train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_59.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
#   train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_6.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
#   train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_60.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
#   train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_61.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
#   train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_62.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
#   train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_63.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
#   train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_64.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
#   train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_65.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
#   train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_66.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
#   train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_67.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
#   train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_68.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
#   train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_69.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
#   train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_7.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
#   train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_70.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
#   train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_71.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
#   train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_72.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
#   train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_73.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
#   train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_74.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
#   train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_75.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
#   train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_76.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
#   train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_77.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
#   train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_78.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
#   train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_79.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
#   train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_8.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
#   train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_80.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
#   train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_81.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
#   train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_82.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
#   train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_83.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
#   train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_84.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
#   train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_85.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
#   train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_86.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
#   train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_87.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
#   train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_88.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
#   train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_89.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
#   train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_9.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
#   train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_90.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
#   train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_91.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
#   train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_92.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
#   train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_93.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
#   train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_94.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
#   train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_95.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
#   train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_96.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
#   train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_97.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
#   train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_98.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
#   train: /Users/anantgambhir/Hello Ji/sameer_project/abc2/images/aggressive_pose_99.jpg: ignoring corrupt image/label: cannot reshape array of size 55 into shape (2)
# See https://docs.ultralytics.com/datasets for dataset formatting guidance.

# %%
# 3. Validate and Export
metrics = model.val()
print(f"Mean Average Precision: {metrics.box.map}")

# Export the trained weights to the models directory for use in detect.py
# path = model.export(format='onnx')
